# %% [markdown]
# ## **Questions based on Titanic Dataset:**
#
# To read the dataset as csv, use the below code:
#
# ```python
# import pandas as pd
#
# url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
# titanic_df = pd.read_csv(url)
# ```

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
titanic_df = pd.read_csv(url)

# %%
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### `Q-1:` Using `groupby` make groups using the `"Pclass"` column and find out the average age and total number of missing values in the `"Age"` column for every group.

# %%
# code here
import numpy as np
pclassGroup = titanic_df.groupby('Pclass')
for group in list(pclassGroup.groups.keys()):
  print(f"Pclass {group}: Average Age: {pclassGroup.get_group(group)['Age'].mean()} and total missing value {pclassGroup.get_group(group)['Age'].isna().sum()}")
# Out:
# Pclass 1: Average Age: 38.233440860215055 and total missing value 30
# Pclass 2: Average Age: 29.87763005780347 and total missing value 11
# Pclass 3: Average Age: 25.14061971830986 and total missing value 136

# %%
print(pclassGroup.get_group(1)['Age'].isna().sum())
# Out:
# 30

# %% [markdown]
# ### `Q-2:` Using `groupby` make groups using the `"Pclass"` column and fill every group's `"Embarked"` column's missing values with the mode value of that group. After that, print every group's `"Embarked"` column's value counts in ascending order.

# %%
# code here
for group in list(pclassGroup.groups.keys()):
  mode = pclassGroup.get_group(group)['Embarked'].mode()
  pclassGroup.get_group(group)['Embarked'].fillna(mode)
  print(f"Pclass {group}: {pclassGroup.get_group(group)['Embarked'].value_counts(ascending=True)}")
# Out:
# Pclass 1: Embarked
# Q      2
# C     85
# S    127
# Name: count, dtype: int64
# Pclass 2: Embarked
# Q      3
# C     17
# S    164
# Name: count, dtype: int64
# Pclass 3: Embarked
# C     66
# Q     72
# S    353
# Name: count, dtype: int64

# %% [markdown]
# ### `Q-3:` Make groups based on `"Embarked"` column. And for each of this embarked group, make another group based on `"Pclass"` and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".
#
# **Sample Output:**
#
# ```bash
# {'C': {1: 105, 2: 25, 3: 11},
#  'Q': {1: 90, 2: 12, 3: 11},
#  'S': {1: 70, 2: 20, 3: 15}}
# ```

# %%
import pandas as pd

# Assuming 'df' is your dataframe and contains the columns 'Embarked', 'Pclass', and 'Fare'

# Group by 'Embarked' and 'Pclass', then calculate the mean fare and round to 2 decimal places
average_fare = titanic_df.groupby(['Embarked', 'Pclass'])['Fare'].mean().round(2)

# Print the result
print(average_fare)
# Out:
# Embarked  Pclass
# C         1         104.72
#           2          25.36
#           3          11.21
# Q         1          90.00
#           2          12.35
#           3          11.18
# S         1          70.36
#           2          20.33
#           3          14.64
# Name: Fare, dtype: float64

# %% [markdown]
# ## **Questions Based on Fifa Worldcup - 2022 Dataset:**
#
# You can read the dataset by using the below sample code
#
# ```python
# import pandas as pd
#
# fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
# ```

# %%
import pandas as pd

fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")

# %%
fifa_df.head(2)
# Out:
#    Sl. No  Match No.     Team  Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar  Ecuador     A     0              40
# 1       2          1  Ecuador    Qatar     A     2              46
#
#    Inside Penalty Area  Outside Penalty Area  Assists  ...  Fouls Against  \
# 0                    0                     0        0  ...             15
# 1                    2                     0        1  ...             15
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
#
# [2 rows x 38 columns]

# %% [markdown]
# ### `Q-4:` Perform `groupby` based on the `"Team"` column and then perform Z Normalization on top of the below columns of each group:
# 1. Passes
# 2. Passes Completed
# 3. Attempted Line Breaks
# 4. Completed Line Breaks
#
# You have to make a python function named `z_normalization` which takes two arguments:
#
# 1. *group:* Every group that you have created
# 2. *cols_to_perform:* This parameter takes a list of columns on which you have to perform the Z-Normalization.
#
# For this problem, you have to use th `apply()` method.
#
# $\Large Z \ - \ Normalization = \frac{X_i - \mu}{std} $
#
# After that find out the below values for each group:
# - minimum "Passess"
# - maximum "Passess"
# - minimum "Yellow Cards"
# - maximum "Yellow cards"
# - average "Yellow Cards"
# - maximum "Attempted Line Breaks"
# - minimum "Attempted Line Breaks"
# - standardard deviation of "Attempted Line Breaks"
# - average Possession

# %%
# code here
def normalize(group,cols):
  for col in cols:
    std = group[col].std()
    mean = group[col].mean()
    group[f"{col}Normalize"]= (group[col]-mean)/std
  return group



cols = ['Passes','Passes Completed','Attempted Line Breaks','Completed Line Breaks']
teamGroup = fifa_df.groupby('Team')
groups = teamGroup.apply(normalize, cols=cols)
groups.groupby('Team').agg(
{
    "Passes": ["min", "max"],
    "Yellow Cards": ["min", "max", "mean"],
    "Attempted Line Breaks": ["max", "min", "std"],
    "Possession (%)": "mean"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-f60a50df643b> in <cell line: 14>()
#      12 teamGroup = fifa_df.groupby('Team')
#      13 groups = teamGroup.apply(normalize, cols=cols)
# ---> 14 groups.groupby('Team').agg(
#      15 {
#      16     "Passes": ["min", "max"],
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8867             raise TypeError("You have to supply one of 'by' and 'level'")
#    8868
# -> 8869         return DataFrameGroupBy(
#    8870             obj=self,
#    8871             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1276
#    1277         if grouper is None:
# -> 1278             grouper, exclusions, obj = get_grouper(
#    1279                 obj,
#    1280                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     997             if obj.ndim != 1 and gpr in obj:
#     998                 if validate:
# --> 999                     obj._check_label_or_level_ambiguity(gpr, axis=axis)
#    1000                 in_axis, name, gpr = True, gpr, obj[gpr]
#    1001                 if gpr.ndim != 1:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1799                 f"{label_article} {label_type} label, which is ambiguous."
#    1800             )
# -> 1801             raise ValueError(msg)
#    1802
#    1803     @final
#
# ValueError: 'Team' is both an index level and a column label, which is ambiguous.

# %% [markdown]
# ## **Questions on IPL wala dataset**
#
# ball by ball dataset - https://drive.google.com/file/d/1-kvv_9KCSAFWcrhS9WgTxSrURkRh6GNt/view?usp=share_link

# %%
ipl = pd.read_csv('/content/ipl_deliveries.csv')

# %%
ipl.sample(5)
# Out:
#             ID                                            Team  innings  \
# 23873  1254107                 Punjab KingsSunrisers Hyderabad        2
# 12834  1304067               Gujarat TitansSunrisers Hyderabad        1
# 26620  1254081                  Rajasthan RoyalsMumbai Indians        1
# 61171  1175356  Royal Challengers BangaloreChennai Super Kings        2
# 16850  1304051             Rajasthan RoyalsSunrisers Hyderabad        2
#
#        overs  ballnumber           batter           bowler non-striker  \
# 23873     13           5        JO Holder    Harpreet Brar     WP Saha
# 12834      2           1     Shubman Gill          B Kumar     MS Wade
# 26620     19           1          R Parag  NM Coulter-Nile   DA Miller
# 61171     12           1        KM Jadhav        YS Chahal   AT Rayudu
# 16850      6           1  Abhishek Sharma  NM Coulter-Nile  AK Markram
#
#       extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 23873        NaN            0           0          0             0
# 12834        NaN            0           0          0             0
# 26620        NaN            4           0          4             0
# 61171        NaN            0           0          0             0
# 16850        NaN            1           0          1             0
#
#        isWicketDelivery player_out kind fielders_involved  \
# 23873                 0        NaN  NaN               NaN
# 12834                 0        NaN  NaN               NaN
# 26620                 0        NaN  NaN               NaN
# 61171                 0        NaN  NaN               NaN
# 16850                 0        NaN  NaN               NaN
#
#                BattingTeam                  BowlingTeam
# 23873  Sunrisers Hyderabad                 Punjab Kings
# 12834       Gujarat Titans          Sunrisers Hyderabad
# 26620     Rajasthan Royals               Mumbai Indians
# 61171  Chennai Super Kings  Royal Challengers Bangalore
# 16850  Sunrisers Hyderabad             Rajasthan Royals

# %%
ipl['player_out'].value_counts()
# Out:
# player_out
# S Dhawan        58
# PP Shaw         54
# Q de Kock       54
# V Kohli         54
# Shubman Gill    53
#                 ..
# K Kartikeya      1
# JL Pattinson     1
# OC McCoy         1
# KS Sharma        1
# M Markande       1
# Name: count, Length: 247, dtype: int64

# %% [markdown]
# ###`Q-5:` Find batsman in below category-
# * Highest score while chasing
# * Best Strike rate while chasing and have faced 100+ balls
#
#
# > Chasing mean team batting in second inning

# %%
# code here
#1
df = ipl[ipl['innings']==2]
df.groupby('batter')['batsman_run'].sum().sort_values(ascending=False)
# Out:
# batter
# KL Rahul        1198
# S Dhawan        1135
# DA Warner        943
# F du Plessis     889
# Shubman Gill     876
#                 ...
# GC Viljoen         0
# JR Philippe        0
# RA Bawa            0
# AS Roy             0
# SS Cottrell        0
# Name: batsman_run, Length: 239, dtype: int64

# %%
#2
tempdf=ipl[~(ipl['extra_type']=='wides')]
tempdf=tempdf.groupby('batter')
tempdf= tempdf.agg({
    'ballnumber':'count',
    'batsman_run':'sum'
})
tempdf["strike_rate"] = tempdf["batsman_run"] / tempdf["ballnumber"] * 100
tempdf[tempdf["ballnumber"] >= 100].sort_values("strike_rate", ascending = False).reset_index().head()
# Out:
#            batter  ballnumber  batsman_run  strike_rate
# 0      AD Russell         645         1149   178.139535
# 1       JC Archer         103          180   174.757282
# 2  LS Livingstone         329          549   166.869301
# 3       JM Sharma         143          234   163.636364
# 4   PBB Rajapaksa         129          206   159.689922

# %% [markdown]
# ###`Q-6` Most Successful bowler against any batsman. Find that pair of bowler and batsman.
# > Most Successful in terms of dissmissal. A bowler who have dissmissed any batsman most no of times. If any two pairs have same no of dissmisal, consider runs conceded by bowler to that batsman. Those who have concede lesser runs is more successful.

# %%
# code here
ipl['isBatterOut']=ipl['batter']==ipl['player_out']
ipl.groupby(['bowler','batter']).agg({
    'isBatterOut':'sum',
    'batsman_run':'sum'
}).sort_values(by=['isBatterOut','batsman_run'],ascending=[False,True]).head()
# Out:
#                            isBatterOut  batsman_run
# bowler         batter
# YS Chahal      MA Agarwal            5           58
# DL Chahar      PP Shaw               5           69
# YS Chahal      Q de Kock             4           22
# Mohammed Shami SO Hetmyer            4           24
# Shivam Mavi    SV Samson             4           30

# %% [markdown]
# ###`Q-7`: Most successful batting pair in IPL. Batting pair who have scored most runs playing together.

# %%
# code here
# code here
def func(x):
    return '-'.join(list(np.sort(x.values)))
ipl["batter-pair"] = ipl[["batter", "non-striker"]].apply(func, axis = 1)
ipl.groupby("batter-pair")["total_run"].sum().sort_values(ascending = False).head()
# Out:
# batter-pair
# KL Rahul-MA Agarwal      1599
# PP Shaw-S Dhawan         1461
# DA Warner-JM Bairstow    1401
# Q de Kock-RG Sharma      1274
# CH Gayle-KL Rahul        1060
# Name: total_run, dtype: int64

# %% [markdown]
# ###`Q-8:` Make a dataframe for all batting pairs played together.
# ```
# Batsman1 Batsman2 Runs Avg StrikeRate
# ```
#
# > Just to ease this question you can count wide-balls for strike rate.

# %%
# code here
# code here
temp_df = ipl.groupby("batter-pair").agg(
{
    "total_run": "sum",
    "ballnumber": "count",
    "isWicketDelivery": "sum"
}).reset_index()
temp_df["Batsman 1"] = temp_df["batter-pair"].apply(lambda x: x.split("-")[0])
temp_df["Batsman 2"] = temp_df["batter-pair"].apply(lambda x: x.split("-")[1])
temp_df.rename(columns = {"total_run": "Runs"}, inplace=True)
temp_df["StrikeRate"] = temp_df["Runs"] / temp_df["ballnumber"] * 100
temp_df["Avg"] = temp_df["Runs"] / temp_df["isWicketDelivery"]
temp_df.sort_values("Runs", ascending = False, inplace=  True)
temp_df[["Batsman 1", "Batsman 2", "Runs", "Avg", "StrikeRate"]]
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        Batsman 1     Batsman 2  Runs        Avg  StrikeRate
# 787     KL Rahul    MA Agarwal  1599  57.107143  139.772727
# 1058     PP Shaw      S Dhawan  1461  33.204545  141.159420
# 389    DA Warner   JM Bairstow  1401  53.884615  144.284243
# 1067   Q de Kock     RG Sharma  1274  33.526316  130.532787
# 304     CH Gayle      KL Rahul  1060  46.086957  131.188119
# ...          ...           ...   ...        ...         ...
# 437     DJ Hooda  PVD Chameera     0   0.000000    0.000000
# 910   MJ Santner        MM Ali     0   0.000000    0.000000
# 222   Avesh Khan  S Lamichhane     0   0.000000    0.000000
# 732   KA Pollard      M Jansen     0   0.000000    0.000000
# 1031    OF Smith     RD Chahar     0   0.000000    0.000000
#
# [1239 rows x 5 columns]
